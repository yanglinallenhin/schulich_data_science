# %%
pip install oct2py
# Out:
# Collecting oct2py
#   Obtaining dependency information for oct2py from https://files.pythonhosted.org/packages/8e/1f/2225791d298f11ab9582e1f2c05b4e8f605d2e166ae6291f65bed4f2d63d/oct2py-5.7.2-py3-none-any.whl.metadata
#   Downloading oct2py-5.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.12 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from oct2py) (1.26.4)
# Collecting octave-kernel>=0.34.0 (from oct2py)
#   Obtaining dependency information for octave-kernel>=0.34.0 from https://files.pythonhosted.org/packages/fd/25/ff1f24b0ddcf4899beb5697d06bf572425eba605f29f9eb577b147b35a8a/octave_kernel-0.36.0-py3-none-any.whl.metadata
#   Downloading octave_kernel-0.36.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: scipy>=0.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from oct2py) (1.13.0)
# Requirement already satisfied: ipykernel in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from octave-kernel>=0.34.0->oct2py) (6.29.4)
# Requirement already satisfied: jupyter-client>=4.3.0 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from octave-kernel>=0.34.0->oct2py) (8.6.1)
# Collecting metakernel>=0.24.0 (from octave-kernel>=0.34.0->oct2py)
#   Obtaining dependency information for metakernel>=0.24.0 from https://files.pythonhosted.org/packages/07/b2/dabf31fd598a777f43e08b33de6540b16df1bd13c1b917ead58ac21bb245/metakernel-0.30.2-py3-none-any.whl.metadata
#   Downloading metakernel-0.30.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (26.0.3)
# Requirement already satisfied: tornado>=6.2 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (6.4)
# Requirement already satisfied: traitlets>=5.3 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (5.14.3)
# Requirement already satisfied: jedi>=0.18 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.19.1)
# Requirement already satisfied: pexpect>=4.8 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (4.9.0)
# Requirement already satisfied: appnope in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (8.24.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (1.6.0)
# Requirement already satisfied: packaging in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (24.0)
# Requirement already satisfied: psutil in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (5.9.8)
# Requirement already satisfied: decorator in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (5.1.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.18.0)
# Requirement already satisfied: stack-data in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from jedi>=0.18->metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (4.2.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from pexpect>=4.8->metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (1.16.0)
# Requirement already satisfied: wcwidth in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/allenyang/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.2)
# Downloading oct2py-5.7.2-py3-none-any.whl (29 kB)
# Downloading octave_kernel-0.36.0-py3-none-any.whl (35 kB)
# Downloading metakernel-0.30.2-py3-none-any.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.8/217.8 kB 4.4 MB/s eta 0:00:0000:01
# Installing collected packages: metakernel, octave-kernel, oct2py
# Successfully installed metakernel-0.30.2 oct2py-5.7.2 octave-kernel-0.36.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import sklearn as sl
import scipy as sp
import seaborn as sb
import matplotlib as mpl
from matplotlib import pyplot as plt
import oct2py as oclib

# %%
year_list = [1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
       2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
josb_assets_list = [101.783,90.671,81.41,77.144,82.515,84.751,88.954,108.457,133.993,186.511,231.83,
                 304.832,368.392,440.098,491.366,556.364,662.037,813.612,894.847,935.738]
mw_assets_list = [160.494,204.105,295.478,379.415,403.732,611.195,707.734,717.869,769.313,869.198,993.322,
               1123.274,1096.952,1256.467,1187.73,1232.106,1320.318,1405.952,1496.347,1555.23]

# %%
plt.figure(figsize=(24,16), dpi= 40)
plt.plot(year_list,josb_assets_list,label="Joseph A Bank",linewidth=8)
plt.plot(year_list,mw_assets_list,'r--',label="Men's Wearhouse",linewidth=8)
xtick_location = np.arange(1994,2013,4)
plt.xticks(ticks=xtick_location, rotation=0, fontsize=50, horizontalalignment='center')
plt.legend(bbox_to_anchor=(0.50, 0.95),fontsize=50)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.xlabel('Year', fontsize = 65)
plt.ylabel('Total Assets', fontsize = 65)
# Out:
# Text(0, 0.5, 'Total Assets')

# %%
random_values = np.random.normal(1000,200,10000)
bins = np.linspace(400,1600,30)
plt.figure(figsize=(24,16), dpi= 40)
plt.hist(random_values,bins)
plt.xlabel('Total Assets', fontsize = 65)
plt.ylabel('Frequency', fontsize = 65)
plt.xticks(fontsize=50)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.title('Histogram of Asset Values in NYSE', fontsize = 65)
# Out:
# Text(0.5, 1.0, 'Histogram of Asset Values in NYSE')

# %%
list_vec = [1,2,3,4]
list_vec + [1]
# Out:
# [1, 2, 3, 4, 1]

# %%
list_vec = [1,2,3,4]
list_vec.append(1)
list_vec
# Out:
# [1, 2, 3, 4, 1]

# %%
import numpy as np
array_vec = np.array([1,2,3,4])
array_vec + np.array([1])
# Out:
# array([2, 3, 4, 5])

# %%
matrix_example = np.array([[1,2,3],[0,-1,2],[1,0,4]])
array_example = np.array([1,-2,1])

# %%
np.dot(matrix_example,array_example)
# Out:
# array([0, 4, 5])

# %%
np.linalg.inv(matrix_example)
# Out:
# array([[-1.33333333, -2.66666667,  2.33333333],
#        [ 0.66666667,  0.33333333, -0.66666667],
#        [ 0.33333333,  0.66666667, -0.33333333]])

# %%
np.transpose(matrix_example)
# Out:
# array([[ 1,  0,  1],
#        [ 2, -1,  0],
#        [ 3,  2,  4]])

# %%
np.linalg.eigvals(matrix_example)
# Out:
# array([ 4.93394491+0.j        , -0.46697245+0.62447535j,
#        -0.46697245-0.62447535j])

# %%
np.linalg.matrix_rank(matrix_example)
# Out:
# 3

# %%
matrix_example
# Out:
# array([[ 1,  2,  3],
#        [ 0, -1,  2],
#        [ 1,  0,  4]])

# %%
matrix_example[0]
# Out:
# array([1, 2, 3])

# %%
np.random.normal(10,2,[10,3])
# Out:
# array([[ 5.16749725, 12.31778872, 12.10368664],
#        [ 6.96252   , 10.91580553, 10.33346129],
#        [12.17814847, 13.02944917,  6.47104722],
#        [ 9.36265171,  9.25419112, 10.80647325],
#        [ 6.64656147,  8.31584486, 10.40903316],
#        [10.75624339, 10.91706229,  9.24899526],
#        [ 8.60847309,  8.41605436,  7.26504033],
#        [10.35713002,  8.51860287,  7.34574172],
#        [11.00632511,  8.73304537, 14.42322551],
#        [11.06571752,  8.26296817, 10.99469286]])

# %%
import scipy as sp

# %%
sp.stats.norm.pdf(14,10,2)
# Out:
# 0.02699548325659403

# %%
sp.stats.norm.isf(1-0.9772498680518208,10,2)
# Out:
# 14.0

# %%
sp.stats.norm.cdf(2,0,1)
# Out:
# 0.9772498680518208

# %%
sp.stats.norm.isf(1-0.9772498680518208,0,1)*2+10
# Out:
# 14.0

# %%
import pandas as pd

# %%
pd.Series(np.random.normal(10,2,8))
# Out:
# 0     2.958922
# 1    10.808362
# 2    10.933852
# 3    11.519458
# 4    11.807073
# 5    11.861034
# 6    10.027288
# 7    11.286293
# dtype: float64

# %%
DataTable = pd.DataFrame(np.random.normal(10,2,[8,3]),columns=list(["column 1", "column 2", "column 3"]))
DataTable
# Out:
#     column 1   column 2   column 3
# 0  14.642126  11.402261  11.335272
# 1   9.107818  10.543445  10.212875
# 2  12.522723   9.968536  11.641743
# 3  10.558614  14.211903   9.479687
# 4  11.376772  10.645792  10.222121
# 5  12.559110  10.602913  12.307852
# 6   8.774796   8.661025   8.170471
# 7   4.938613  10.424990   8.041845

# %%
DataTable[DataTable["column 1"]>13]
# Out:
#     column 1   column 2   column 3
# 0  14.642126  11.402261  11.335272

# %%
import pandas as pd
input_table = pd.read_csv('sales_data.csv')
input_table.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 2
#       1 import pandas as pd
# ----> 2 input_table = pd.read_csv('sales_data.csv')
#       3 input_table.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sales_data.csv'
